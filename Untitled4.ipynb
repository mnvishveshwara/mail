# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'mail.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import*


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(740, 575)
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(60, 90, 151, 51))
        self.label.setStyleSheet("color: rgb(255, 0, 0);\n"
"font: 18pt \"Arial\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(60, 190, 161, 31))
        self.label_2.setStyleSheet("color: rgb(255, 0, 0);\n"
"font: 75 italic 18pt \"Arial\";")
        self.label_2.setObjectName("label_2")
        self.fname = QtWidgets.QLineEdit(Form)
        self.fname.setGeometry(QtCore.QRect(230, 90, 451, 41))
        self.fname.setObjectName("fname")
        self.lname = QtWidgets.QLineEdit(Form)
        self.lname.setGeometry(QtCore.QRect(230, 180, 451, 51))
        self.lname.setObjectName("lname")
        self.fnum = QtWidgets.QLineEdit(Form)
        self.fnum.setGeometry(QtCore.QRect(230, 260, 451, 51))
        self.fnum.setObjectName("fnum")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(50, 280, 171, 31))
        self.label_3.setStyleSheet("color: rgb(255, 0, 0);\n"
"font: 75 italic 18pt \"Arial\";")
        self.label_3.setObjectName("label_3")
        self.pushButton = QtWidgets.QPushButton(Form)
        self.pushButton.setGeometry(QtCore.QRect(300, 360, 141, 41))
        self.pushButton.setStyleSheet("color:rgb(255, 85, 0);\n"
"font: 75 italic 14pt \"Arial\";")
        self.pushButton.setObjectName("pushButton")
        self.pushButton.clicked.connect(self.mail)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
    def mail(self):
        fn=self.fname.text()
        ln=self.lname.text()
        fnm=self.fnum.text()
        output=fn+ln+fnm+"@gmail.com"
        if len(fn)<1:
            QMessageBox.information(None,"incomplete data ","Please fill first name")
        elif len(ln)<1:
            QMessageBox.information(None,"incomplete data ","Please fill last name")
        elif len(fnm)<1:
            QMessageBox.information(None,"incomplete data ","Please fill fvt number")
        else:
             print("login sucessful",fn,ln,fnm,output)
        
        

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "First name:"))
        self.label_2.setText(_translate("Form", "Last Name:"))
        self.label_3.setText(_translate("Form", "Fvt Number:"))
        self.pushButton.setText(_translate("Form", "Submit"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\Vishva\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3377: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
